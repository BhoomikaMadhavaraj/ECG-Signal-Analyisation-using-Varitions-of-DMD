# %%
import pandas as  pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
data=pd.read_csv("/home/senume/Project/MIS/mis-ECG_analysis_DMD/FEATURE_EXTRACTION/Base Paper/BEAT/Features_Beat_Bundle branch block.csv")
data = data.drop(['name'], axis = 1)
sns.heatmap(data.corr(), cmap="YlGnBu")
plt.show()

# %%
X=data[data.columns[6:]]
vif = pd.DataFrame()
vif["features"] = X.columns
vif["vif_Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
print(vif)

# %%
M_Vector = [ n for n in data.columns if n.startswith('M')]
P_Vector = [ n for n in data.columns if n.startswith('P')]

eigs_Parameters = data.columns[1:6]
# Out:
# Index(['R_Lambda', 'Lam_min', 'Lam_max', 'R_M', 'R_P'], dtype='object')

# %%
sns.heatmap(data[M_Vector].corr(), cmap="YlGnBu")
plt.show()

# %%
sns.heatmap(data[P_Vector].corr(), cmap="YlGnBu")
plt.show()

# %%
sns.heatmap(data[eigs_Parameters[2:]].corr(), cmap="YlGnBu")
plt.show()
